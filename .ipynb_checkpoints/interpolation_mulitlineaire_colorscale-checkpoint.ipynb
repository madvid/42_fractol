# %%
2+2
# Out:
# 4

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
mako_palette = sns.color_palette("mako", as_cmap=True)
viridis_palette = sns.color_palette("viridis", as_cmap=True)
magma_palette = sns.color_palette("magma", as_cmap=True)
ylorbr_palette = sns.color_palette("YlOrBr", as_cmap=True)
coolwarm_palette = sns.color_palette("coolwarm", as_cmap=True)
red_palette = sns.color_palette("Reds", as_cmap=True)
blue_palette = sns.color_palette("Blues", as_cmap=True)
green_palette = sns.color_palette("Greens", as_cmap=True)

# %%
mako_palette_RGB = [(mako_palette(int(i))[0]*255, mako_palette(int(i))[1]*255, mako_palette(int(i))[2]*255) for i in np.linspace(0,255, 100)]
viridis_palette_RGB = [(viridis_palette(int(i))[0]*255, viridis_palette(int(i))[1]*255, viridis_palette(int(i))[2]*255) for i in np.linspace(0,255, 100)]
magma_palette_RGB = [(magma_palette(int(i))[0]*255, magma_palette(int(i))[1]*255, magma_palette(int(i))[2]*255) for i in np.linspace(0,255, 100)]
ylorbr_palette_RGB = [(ylorbr_palette(int(i))[0]*255, ylorbr_palette(int(i))[1]*255, ylorbr_palette(int(i))[2]*255) for i in np.linspace(0,255, 100)]
coolwarm_palette_RGB = [(coolwarm_palette(int(i))[0]*255, coolwarm_palette(int(i))[1]*255, coolwarm_palette(int(i))[2]*255) for i in np.linspace(0,255, 100)]
red_palette_RGB = [(red_palette(int(i))[0]*255, red_palette(int(i))[1]*255, red_palette(int(i))[2]*255) for i in np.linspace(0,255, 100)]
blue_palette_RGB = [(blue_palette(int(i))[0]*255, blue_palette(int(i))[1]*255, blue_palette(int(i))[2]*255) for i in np.linspace(0,255, 100)]
green_palette_RGB = [(green_palette(int(i))[0]*255, green_palette(int(i))[1]*255, green_palette(int(i))[2]*255) for i in np.linspace(0,255, 100)]

# %%
def convert_dataframe(palette):
    l_red = []
    l_blue = []
    l_green = []
    for elem in palette:
        l_red.append(elem[0])
        l_blue.append(elem[1])
        l_green.append(elem[2])
    df = pd.DataFrame({"red":l_red, "blue":l_blue, "green":l_green})
    return (df)

# %%
df_mako = convert_dataframe(mako_palette_RGB)
df_viridis = convert_dataframe(viridis_palette_RGB)
df_magma = convert_dataframe(magma_palette_RGB)
df_ylorbr = convert_dataframe(ylorbr_palette_RGB)
df_coolwarm = convert_dataframe(coolwarm_palette_RGB)
df_red = convert_dataframe(red_palette_RGB)
df_blue = convert_dataframe(blue_palette_RGB)
df_green = convert_dataframe(green_palette_RGB)

# %%
fig, axes = plt.subplots(3,3, figsize=(20,20))

axes[0][0].plot(df_mako["red"], label="red", color="red")
axes[0][0].plot(df_mako["blue"], label="blue", color="blue")
axes[0][0].plot(df_mako["green"], label="green", color="green")
axes[0][0].set_title("color palette mako")

axes[0][1].plot(df_viridis["red"], label="red", color="red")
axes[0][1].plot(df_viridis["blue"], label="blue", color="blue")
axes[0][1].plot(df_viridis["green"], label="green", color="green")
axes[0][1].set_title("color palette viridis")

axes[0][2].plot(df_magma["red"], label="red", color="red")
axes[0][2].plot(df_magma["blue"], label="blue", color="blue")
axes[0][2].plot(df_magma["green"], label="green", color="green")
axes[0][2].set_title("color palette magma")

axes[1][0].plot(df_ylorbr["red"], label="red", color="red")
axes[1][0].plot(df_ylorbr["blue"], label="blue", color="blue")
axes[1][0].plot(df_ylorbr["green"], label="green", color="green")
axes[1][0].set_title("color palette ylorbr")

axes[1][1].plot(df_coolwarm["red"], label="red", color="red")
axes[1][1].plot(df_coolwarm["blue"], label="blue", color="blue")
axes[1][1].plot(df_coolwarm["green"], label="green", color="green")
axes[1][1].set_title("color palette coolwarm")

axes[1][2].plot(df_red["red"], label="red", color="red")
axes[1][2].plot(df_red["blue"], label="blue", color="blue")
axes[1][2].plot(df_red["green"], label="green", color="green")
axes[1][2].set_title("color palette red")

axes[2][0].plot(df_blue["red"], label="red", color="red")
axes[2][0].plot(df_blue["blue"], label="blue", color="blue")
axes[2][0].plot(df_blue["green"], label="green", color="green")
axes[2][0].set_title("color palette blue")

axes[2][1].plot(df_green["red"], label="red", color="red")
axes[2][1].plot(df_green["blue"], label="blue", color="blue")
axes[2][1].plot(df_green["green"], label="green", color="green")
axes[2][1].set_title("color palette green")
# Out:
# Text(0.5, 1.0, 'color palette green')

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error as mse

# %%
#df_mako, df_viridis, df_magma, df_coolwarm, df_ylorbr, df_blue, df_red, df_green
df_cible = df_green
cible = "Greens"

# %%
X1 = df_cible.index
X2 = np.power(df_cible.index, 2)
X3 = np.power(df_cible.index, 3)
X4 = np.power(df_cible.index, 4)
X5 = np.power(df_cible.index, 5)
X6 = np.power(df_cible.index, 6)

X = np.array([X1, X2, X3, X4, X5, X6])
X = X.T

y_red = df_cible["red"]
y_blue = df_cible["blue"]
y_green = df_cible["green"]

# %%
reg_red_1 = LinearRegression().fit(X[:,:1], y_red)
reg_red_2 = LinearRegression().fit(X[:,:2], y_red)
reg_red_3 = LinearRegression().fit(X[:,:3], y_red)
reg_red_4 = LinearRegression().fit(X[:,:4], y_red)
reg_red_5 = LinearRegression().fit(X[:,:5], y_red)
reg_red_6 = LinearRegression().fit(X[:,:6], y_red)

# %%
reg_blue_1 = LinearRegression().fit(X[:,:1], y_blue)
reg_blue_2 = LinearRegression().fit(X[:,:2], y_blue)
reg_blue_3 = LinearRegression().fit(X[:,:3], y_blue)
reg_blue_4 = LinearRegression().fit(X[:,:4], y_blue)
reg_blue_5 = LinearRegression().fit(X[:,:5], y_blue)
reg_blue_6 = LinearRegression().fit(X[:,:6], y_blue)

# %%
reg_green_1 = LinearRegression().fit(X[:,:1], y_green)
reg_green_2 = LinearRegression().fit(X[:,:2], y_green)
reg_green_3 = LinearRegression().fit(X[:,:3], y_green)
reg_green_4 = LinearRegression().fit(X[:,:4], y_green)
reg_green_5 = LinearRegression().fit(X[:,:5], y_green)
reg_green_6 = LinearRegression().fit(X[:,:6], y_green)

# %%
pred_red_1 = reg_red_1.predict(X[:,:1])
pred_red_2 = reg_red_2.predict(X[:,:2])
pred_red_3 = reg_red_3.predict(X[:,:3])
pred_red_4 = reg_red_4.predict(X[:,:4])
pred_red_5 = reg_red_5.predict(X[:,:5])
pred_red_6 = reg_red_6.predict(X[:,:6])

# %%
pred_blue_1 = reg_blue_1.predict(X[:,:1])
pred_blue_2 = reg_blue_2.predict(X[:,:2])
pred_blue_3 = reg_blue_3.predict(X[:,:3])
pred_blue_4 = reg_blue_4.predict(X[:,:4])
pred_blue_5 = reg_blue_5.predict(X[:,:5])
pred_blue_6 = reg_blue_6.predict(X[:,:6])

# %%
pred_green_1 = reg_green_1.predict(X[:,:1])
pred_green_2 = reg_green_2.predict(X[:,:2])
pred_green_3 = reg_green_3.predict(X[:,:3])
pred_green_4 = reg_green_4.predict(X[:,:4])
pred_green_5 = reg_green_5.predict(X[:,:5])
pred_green_6 = reg_green_6.predict(X[:,:6])

# %%
fig, axe = plt.subplots(1,3, figsize=(30,10))

axe[0].plot(df_cible["red"], label="red", color="red")
axe[0].plot(pred_red_1, label="pred 1", color="lightgray")
axe[0].plot(pred_red_2, label="pred 2", color="darkgray")
axe[0].plot(pred_red_4, label="pred 3", color="dimgrey")
axe[0].plot(pred_red_6, label="pred 4", color="black")
axe[0].set_title(f"Ajustement du rouge de {cible} palette")

axe[2].plot(df_cible["blue"], label="red", color="blue")
axe[2].plot(pred_blue_1, label="pred 1", color="lightgray")
axe[2].plot(pred_blue_2, label="pred 2", color="darkgray")
axe[2].plot(pred_blue_4, label="pred 3", color="dimgrey")
axe[2].plot(pred_blue_6, label="pred 4", color="black")
axe[2].set_title(f"Ajustement du bleu de {cible} palette")

axe[1].plot(df_cible["green"], label="red", color="green")
axe[1].plot(pred_green_1, label="pred 1", color="lightgray")
axe[1].plot(pred_green_2, label="pred 2", color="darkgray")
axe[1].plot(pred_green_4, label="pred 3", color="dimgrey")
axe[1].plot(pred_green_6, label="pred 4", color="black")
axe[1].set_title(f"Ajustement du vert de {cible} palette")

plt.legend()
plt.show()

# %%
# Preformatage pour mon code C:

# conversion en string des coefficient du modele:
coeff_red = [f"{reg_red_6.intercept_:.1f}", f"{reg_red_6.coef_[0]:.3f}", f"{reg_red_6.coef_[1]:.5f}", f"{reg_red_6.coef_[2]:.7f}", f"{reg_red_6.coef_[3]:.10f}"]
coeff_green = [f"{reg_green_6.intercept_:.2f}", f"{reg_green_6.coef_[0]:.3f}", f"{reg_green_6.coef_[1]:.5f}", f"{reg_green_6.coef_[2]:.7f}", f"{reg_green_6.coef_[3]:.10f}"]
coeff_blue = [f"{reg_blue_6.intercept_:.2f}", f"{reg_blue_6.coef_[0]:.3f}", f"{reg_blue_6.coef_[1]:.5f}", f"{reg_blue_6.coef_[2]:.7f}", f"{reg_blue_6.coef_[3]:.10f}"]

print(f"c.r = (unsigned char)({coeff_red[1]} * level +{coeff_red[2]} * pow(level, 2) +{coeff_red[3]} * pow(level, 3) +{coeff_red[4]} * pow(level, 4) +{coeff_red[0]});")
print(f"c.b = (unsigned char)({coeff_green[1]} * level +{coeff_green[2]} * pow(level, 2) +{coeff_green[3]} * pow(level, 3) +{coeff_green[4]} * pow(level, 4) +{coeff_green[0]});")
print(f"c.g = (unsigned char)({coeff_blue[1]} * level +{coeff_blue[2]} * pow(level, 2) +{coeff_blue[3]} * pow(level, 3) +{coeff_blue[4]} * pow(level, 4) +{coeff_blue[0]});")
# Out:
# c.r = (unsigned char)(-1.813 * level +0.04956 * pow(level, 2) +-0.0036134 * pow(level, 3) +0.0000695342 * pow(level, 4) +248.0);
# c.b = (unsigned char)(-1.662 * level +0.02270 * pow(level, 2) +-0.0033476 * pow(level, 3) +0.0000867158 * pow(level, 4) +245.08);
# c.g = (unsigned char)(-0.099 * level +-0.05145 * pow(level, 2) +0.0017250 * pow(level, 3) +-0.0000367276 * pow(level, 4) +251.31);

# %%
# Preformatage pour mon code C:

# conversion en string des coefficient du modele:
coeff_red = [f"{reg_red_6.intercept_:.1f}", f"{reg_red_6.coef_[0]:.3f}", f"{reg_red_6.coef_[1]:.5f}", f"{reg_red_6.coef_[2]:.7f}", f"{reg_red_6.coef_[3]:.9f}", f"{reg_red_6.coef_[4]:.11f}", f"{reg_red_6.coef_[5]:.13f}"]
coeff_green = [f"{reg_green_6.intercept_:.2f}", f"{reg_green_6.coef_[0]:.3f}", f"{reg_green_6.coef_[1]:.5f}", f"{reg_green_6.coef_[2]:.7f}", f"{reg_green_6.coef_[3]:.9f}", f"{reg_green_6.coef_[4]:.11f}", f"{reg_green_6.coef_[5]:.13f}"]
coeff_blue = [f"{reg_blue_6.intercept_:.2f}", f"{reg_blue_6.coef_[0]:.3f}", f"{reg_blue_6.coef_[1]:.5f}", f"{reg_blue_6.coef_[2]:.7f}", f"{reg_blue_6.coef_[3]:.9f}", f"{reg_blue_6.coef_[4]:.11f}", f"{reg_blue_6.coef_[5]:.13f}"]

print(f"c.r = (unsigned char)({coeff_red[1]} * level +{coeff_red[2]} * pow(level, 2) +{coeff_red[3]} * pow(level, 3) +{coeff_red[4]} * pow(level, 4) +{coeff_red[5]} * pow(level, 5) +{coeff_red[6]} * pow(level, 6) +{coeff_red[0]});")
print(f"c.b = (unsigned char)({coeff_green[1]} * level +{coeff_green[2]} * pow(level, 2) +{coeff_green[3]} * pow(level, 3) +{coeff_green[4]} * pow(level, 4) +{coeff_green[5]} * pow(level, 5) +{coeff_green[6]} * pow(level, 6) +{coeff_green[0]});")
print(f"c.g = (unsigned char)({coeff_blue[1]} * level +{coeff_blue[2]} * pow(level, 2) +{coeff_blue[3]} * pow(level, 3) +{coeff_blue[4]} * pow(level, 4) +{coeff_blue[5]} * pow(level, 5) +{coeff_blue[6]} * pow(level, 6) +{coeff_blue[0]});")
# Out:
# c.r = (unsigned char)(-1.813 * level +0.04956 * pow(level, 2) +-0.0036134 * pow(level, 3) +0.000069534 * pow(level, 4) +-0.00000057705 * pow(level, 5) +0.0000000018706 * pow(level, 6) +248.0);
# c.b = (unsigned char)(-1.662 * level +0.02270 * pow(level, 2) +-0.0033476 * pow(level, 3) +0.000086716 * pow(level, 4) +-0.00000086794 * pow(level, 5) +0.0000000030781 * pow(level, 6) +245.08);
# c.g = (unsigned char)(-0.099 * level +-0.05145 * pow(level, 2) +0.0017250 * pow(level, 3) +-0.000036728 * pow(level, 4) +0.00000035709 * pow(level, 5) +-0.0000000012864 * pow(level, 6) +251.31);

# %%
idx = 0
print(reg_red_4.predict(X[:,:4])[idx], reg_green_4.predict(X[:,:4])[idx], reg_blue_4.predict(X[:,:4])[idx])
# Out:
# 245.6720954765912 243.96841458147452 251.5872666218223

# %%
idx = 0
print(reg_red_6.predict(X[:,:6])[idx], reg_green_6.predict(X[:,:6])[idx], reg_blue_6.predict(X[:,:6])[idx])
# Out:
# 252.9032294148792 238.7641567565505 242.3755655949023

# %%
viridis_palette_RGB
# Out:
# [(68.08602, 1.24287, 84.000825),
#  (68.83572000000001, 3.729375, 87.051645),
#  (69.821295, 8.031735, 91.507515),
#  (70.38561, 11.262585, 94.39182),
#  (71.091705, 15.846975, 98.58096),
#  (71.468085, 18.721335, 101.27656499999999),
#  (71.89062, 22.864829999999998, 105.165825),
#  (72.14205, 26.875215, 108.86001),
#  (72.21523499999999, 29.4984, 111.20932499999999),
#  (72.18336, 33.378225, 114.556455),
#  (72.068865, 35.93613, 116.666835),
#  (71.76006, 39.73767, 119.646255),
#  (71.465025, 42.251715000000004, 121.50698999999999),
#  (70.89305999999999, 45.993585, 124.10773499999999),
#  (70.173705, 49.700775, 126.481275),
#  (69.61653000000001, 52.1526, 127.93885499999999),
#  (68.67354, 55.798590000000004, 129.94213499999998),
#  (67.97789999999999, 58.20681, 131.15899499999998),
#  (66.84519, 61.78293, 132.813435),
#  (66.036075, 64.141935, 133.80768),
#  (64.75342500000001, 67.63977, 135.145665),
#  (63.400394999999996, 71.087625, 136.31178),
#  (62.46786, 73.35712500000001, 137.0013),
#  (61.03323, 76.718025, 137.91522),
#  (60.05913, 78.929385, 138.45072),
#  (58.583445, 82.202055, 139.15503),
#  (57.595065000000005, 84.355275, 139.56507),
#  (56.114535000000004, 87.543285, 140.10031500000002),
#  (54.64599, 90.682845, 140.55192),
#  (53.678264999999996, 92.75038500000001, 140.81252999999998),
#  (52.250265, 95.81523, 141.15091500000003),
#  (51.315945, 97.83585000000001, 141.34497),
#  (49.9443, 100.835415, 141.59538),
#  (48.610904999999995, 103.800555, 141.80269500000003),
#  (47.743905000000005, 105.76023, 141.919485),
#  (46.47528, 108.67692, 142.0656),
#  (45.649845000000006, 110.60777999999999, 142.14464999999998),
#  (44.439870000000006, 113.48622, 142.23695999999998),
#  (43.649879999999996, 115.39515, 142.28107500000002),
#  (42.487334999999995, 118.24554, 142.320345),
#  (41.34621, 121.08368999999999, 142.32569999999998),
#  (40.59447, 122.97043500000001, 142.308615),
#  (39.477825, 125.794815, 142.2492),
#  (38.73909, 127.67467500000001, 142.184685),
#  (37.639784999999996, 130.491915, 142.047495),
#  (36.913545, 132.368715, 141.92586),
#  (35.83668, 135.18366, 141.693045),
#  (34.78404, 137.99911500000002, 141.39316499999998),
#  (34.104465, 139.876425, 141.152955),
#  (33.132915, 142.69341, 140.72532),
#  (32.52984, 144.57199500000002, 140.39178),
#  (31.720725, 147.39051, 139.813185),
#  (31.26453, 149.26960499999998, 139.37203499999998),
#  (30.744075000000002, 152.08761, 138.620805),
#  (30.475559999999998, 154.90332, 137.75558999999998),
#  (30.468165000000003, 156.778335, 137.11146),
#  (30.76269, 159.58614, 136.03943999999998),
#  (31.18956, 161.454015, 135.25149000000002),
#  (32.21313, 164.247285, 133.954305),
#  (33.167085, 166.10291999999998, 133.01004),
#  (35.021445, 168.87426, 131.470605),
#  (37.38708, 171.62775000000002, 129.77868),
#  (39.24297, 173.451765, 128.56385999999998),
#  (42.427665, 176.16828, 126.60801),
#  (44.805285, 177.9645, 125.213415),
#  (48.72795, 180.63333, 122.98241999999999),
#  (53.04765, 183.268755, 120.58261499999999),
#  (56.13162, 185.004795, 118.88762999999999),
#  (61.04037, 187.57494, 116.20044),
#  (64.489245, 189.263805, 114.31242),
#  (69.907995, 191.75694, 111.33325500000001),
#  (73.674855, 193.39047, 109.24862999999999),
#  (79.540875, 195.79461, 105.97443),
#  (85.65067499999999, 198.13959, 102.52249499999999),
#  (89.8518, 199.66780500000002, 100.12218),
#  (96.33364499999999, 201.904155, 96.37444500000001),
#  (100.76937000000001, 203.35612500000002, 93.778035),
#  (107.58654, 205.47236999999998, 89.73705),
#  (112.23493500000001, 206.84019, 86.946585),
#  (119.353515, 208.824855, 82.61949),
#  (126.63682499999999, 210.72588, 78.126135),
#  (131.57796, 211.94529, 75.041145),
#  (139.10862, 213.69994499999999, 70.28462999999999),
#  (144.20199, 214.81965, 67.033635),
#  (151.938945, 216.42283500000002, 62.048894999999995),
#  (157.15471499999998, 217.440795, 58.66326),
#  (165.050535, 218.89200000000002, 53.514555),
#  (173.014695, 220.25421, 48.323265),
#  (178.35082500000001, 221.114835, 44.872605),
#  (186.376695, 222.33858, 39.787395000000004),
#  (191.73042, 223.112505, 36.52314),
#  (199.745325, 224.21767499999999, 31.978274999999996),
#  (205.06641, 224.92173, 29.316074999999998),
#  (212.99384999999998, 225.93739499999998, 26.17473),
#  (220.833315, 226.91634, 24.468014999999998),
#  (225.99910500000001, 227.55537, 24.32037),
#  (233.64171, 228.50320499999998, 25.682835),
#  (238.65552, 229.13535, 27.573405),
#  (246.04797000000002, 230.092365, 31.604955),
#  (253.27824, 231.070035, 36.703680000000006)]
